# %%
# Lidar com Tempo de espera
import time
from time import sleep

############################### SELENIUM ###############################
from selenium import webdriver # navegador

# Ações ###############################
from selenium.webdriver.common.by import By # localizar elementos
from selenium.webdriver.common.keys import Keys # comandos do teclado
from selenium.webdriver.common.action_chains import ActionChains # ações do mouse e teclado

# Exceções|Erros e Espera ###############################
from selenium.common.exceptions import NoSuchElementException # exceção para elementos não encontrados # CONTROLE DE ERROS
from selenium.webdriver.support.ui import WebDriverWait # esperar

# condições de espera ###############################
from selenium.webdriver.support.expected_conditions import (visibility_of, staleness_of, invisibility_of_element, visibility_of_element_located)
from selenium.webdriver.support import expected_conditions as EC # condições de espera (atalho)
from selenium.common.exceptions import TimeoutException # exceção para tempo limite

## ChromeDriver ###############################
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
browser = webdriver.Chrome(service=Service(ChromeDriverManager().install()))

# Entrar no Site
browser.get('https://www.sofascore.com/pt/football/team/brazil/4748#tab:statistics'); sleep(5)

# %%
# Requisições HTTP
import requests
from bs4 import BeautifulSoup

# %%
setor_html = browser.find_element("xpath", '//*[@id="tabpanel-statistics"]/div/div[3]/div/div[1]').get_attribute('outerHTML')
soup = BeautifulSoup(setor_html, 'html.parser')

for i in soup.find_all(class_="px_lg py_sm"):
    print(i.get_text())
# Out:
# Gols por partida1.3
# Gols de pênalti3/5
# Gols de falta1/14
# Gols de dentro da área19/135
# Gols de fora da área5/80
# Gols com a perna esquerda10
# Gols com a perna direita10
# Gols de cabeça4
# Grandes chances de gol por jogo2.1
# Grandes chances perdidas por jogo1.4
# Total de finalizações por jogo11.9
# Chutes certos por jogo4.2
# Chutes errados por jogo4.3
# Chutes bloqueados por jogo3.4
# Dribles certos por jogo7.8
# Escanteios por jogo5.1
# Faltas (Tiros Diretos) por jogo14.7
# Finalizações na trave8
# Contra-ataques5
