# %% [markdown]
# # Coleta de Dados de informações dos jogos

# %%
# Importando Bibliotecas de conexão
import mysql.connector
import selenium

# %%
# Acessando o banco de dados
bd = mysql.connector.connect(
    host = "localhost",
    user = "root",
    password = "raphael",
    database = "World_Cup_26"
)

mycursor = bd.cursor()

mycursor.execute("SELECT * FROM seleções")

for x in mycursor:
  print(x)
# Out:
# (4400, 'Coreia do Sul', 'KOR', 'AFC', 22, 'A')
# (4405, 'Iraque', 'IRQ', 'AFC', 58, 'I')
# (4406, 'Catar', 'QAT', 'AFC', 37, 'B')
# (4407, 'Irã', 'IRN', 'AFC', 20, 'G')
# (4408, 'Austrália', 'AUS', 'AFC', 24, 'D')
# (4409, 'Jordânia', 'JOR', 'AFC', 71, 'J')
# (4411, 'Arábia Saudita', 'KSA', 'AFC', 53, 'H')
# (4412, 'Japão', 'JPN', 'AFC', 18, 'F')
# (4413, 'Uzbequistão', 'UZB', 'AFC', 64, 'K')
# (4422, 'Uruguai', 'URU', 'CONMEBOL', 11, 'H')
# (4424, 'Nova Zelândia', 'NZL', 'OFC', 103, 'G')
# (4425, 'Brasil', 'BRA', 'CONMEBOL', 5, 'C')
# (4438, 'Inglaterra', 'ENG', 'UEFA', 4, 'L')
# (4480, 'França', 'FRA', 'UEFA', 2, 'I')
# (4481, 'Argentina', 'ARG', 'CONMEBOL', 1, 'J')
# (4482, 'Alemanha', 'GER', 'UEFA', 16, 'E')
# (4483, 'Portugal', 'POR', 'UEFA', 6, 'K')
# (4485, 'Bélgica', 'BEL', 'UEFA', 8, 'G')
# (4486, 'Escócia', 'SCO', 'UEFA', 39, 'C')
# (4488, 'Noruega', 'NOR', 'UEFA', 47, 'I')
# (4489, 'Suíça', 'SUI', 'UEFA', 19, 'B')
# (4491, 'Suécia', 'SWE', 'UEFA', 28, 'F')
# (4492, 'Holanda', 'NED', 'UEFA', 7, 'F')
# (4493, 'Espanha', 'ESP', 'UEFA', 3, 'H')
# (4494, 'Croácia', 'CRO', 'UEFA', 10, 'L')
# (4691, 'Argélia', 'ALG', 'CAF', 43, 'J')
# (4697, 'Bósnia e Herzegovina', 'BIH', 'UEFA', 74, 'B')
# (4703, 'Turquia', 'TUR', 'UEFA', 35, 'D')
# (4705, 'Tchéquia', 'CZE', 'UEFA', 40, 'A')
# (4711, 'Áustria', 'AUT', 'UEFA', 25, 'J')
# (4717, 'Panamá', 'PAN', 'CONCACAF', 43, 'L')
# (4720, 'Curaçao', 'CUW', 'CONCACAF', 91, 'E')
# (4722, 'Haiti', 'HAI', 'CONCACAF', 90, 'C')
# (4724, 'Canadá', 'CAN', 'CONCACAF', 40, 'B')
# (4725, 'EUA', 'USA', 'CONCACAF', 13, 'D')
# (4734, 'México', 'MEX', 'CONCACAF', 15, 'A')
# (4740, 'África do Sul', 'RSA', 'CAF', 59, 'A')
# (4741, 'Marrocos', 'MAR', 'CAF', 13, 'C')
# (4742, 'Cabo Verde', 'CPV', 'CAF', 65, 'H')
# (4744, 'Egito', 'EGY', 'CAF', 36, 'G')
# (4745, 'Costa do Marfim', 'CIV', 'CAF', 38, 'E')
# (4746, 'RD Congo', 'COD', 'CAF', 63, 'K')
# (4747, 'Gana', 'GHA', 'CAF', 68, 'L')
# (4754, 'Senegal', 'SEN', 'CAF', 17, 'I')
# (4755, 'Tunísia', 'TUN', 'CAF', 41, 'F')
# (4819, 'Equador', 'ECU', 'CONMEBOL', 31, 'E')
# (4820, 'Colômbia', 'COL', 'CONMEBOL', 12, 'K')
# (4823, 'Paraguai', 'PAR', 'CONMEBOL', 56, 'D')

# %%
mycursor.execute("SELECT * FROM seleções")

# %%
grupo_a = []
grupo_b = []
grupo_c = []
grupo_d = []
grupo_e = []
grupo_f = []
grupo_g = []
grupo_h = []
grupo_i = []
grupo_j = []
grupo_k = []
grupo_l = []

# %%
# O loop começa aqui
for x in mycursor:
    # Criamos uma variável temporária para facilitar a leitura e limpar o dado
    grupo_atual = x[5].strip().upper()
    
    if grupo_atual == "A":
        grupo_a.append(x)
    elif grupo_atual == "B":
        grupo_b.append(x)
    elif grupo_atual == "C":
        grupo_c.append(x)
    elif grupo_atual == "D":
        grupo_d.append(x)
    elif grupo_atual == "E":
        grupo_e.append(x)
    elif grupo_atual == "F":
        grupo_f.append(x)
    elif grupo_atual == "G":
        grupo_g.append(x)
    elif grupo_atual == "H":
        grupo_h.append(x)
    elif grupo_atual == "I":
        grupo_i.append(x)
    elif grupo_atual == "J":
        grupo_j.append(x)
    elif grupo_atual == "K":
        grupo_k.append(x)
    elif grupo_atual == "L":
        grupo_l.append(x)
    else:
        
        print(f"Atenção: Seleção {x[1]} está num grupo fora de A-L: {x[5]}")

# %%
print("-" * 20)
print(f"Grupo A: {len(grupo_a)} times")
print(f"Grupo B: {len(grupo_b)} times")
print(f"Grupo C: {len(grupo_c)} times")
# ... continue para os outros
print("-" * 20)
# Out:
# --------------------
# Grupo A: 4 times
# Grupo B: 4 times
# Grupo C: 4 times
# --------------------

# %%
dados = mycursor.fetchall()

# %%
# Lidar com Tempo de espera
import time
from time import sleep

############################### SELENIUM ###############################
from selenium import webdriver # navegador

# Ações ###############################
from selenium.webdriver.common.by import By # localizar elementos
from selenium.webdriver.common.keys import Keys # comandos do teclado
from selenium.webdriver.common.action_chains import ActionChains # ações do mouse e teclado

# Exceções|Erros e Espera ###############################
from selenium.common.exceptions import NoSuchElementException # exceção para elementos não encontrados # CONTROLE DE ERROS
from selenium.webdriver.support.ui import WebDriverWait # esperar

# condições de espera ###############################
from selenium.webdriver.support.expected_conditions import (visibility_of, staleness_of, invisibility_of_element, visibility_of_element_located)
from selenium.webdriver.support import expected_conditions as EC # condições de espera (atalho)
from selenium.common.exceptions import TimeoutException # exceção para tempo limite

## ChromeDriver ###############################
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
browser = webdriver.Chrome(service=Service(ChromeDriverManager().install()))

browser.get('https://www.sofascore.com/pt/football/team/brazil/4748#tab:statistics')

# %%
# Requisições HTTP
import requests
from bs4 import BeautifulSoup
import pyautogui

# %% [markdown]
# # Pegando um caso

# %%
pais = 'Iraque'

# %%
print(pais)

# Barra pesquisar
pesquisa = browser.find_element("xpath", '//*[@id="search-trigger-button"]/div')
pesquisa.click()

# Digitar a seleção
try:
    digite = browser.find_element("xpath", '//*[@id="search-input"]')
    digite.click()
    digite.send_keys(pais)
    print('Selenium')
except:
    pyautogui.click(410, 137)
    pyautogui.write(pais)
    time.sleep(2)
    print('pyautogui')

# Selecionar o pais
try:
    selecione = browser.find_element('xpath', '/html/body/div[6]/div[2]/div/div[2]/div/div[1]/a/div')
    selecione.click()
    selecione.click()
    print('Selenium')
except:
    pyautogui.click(377, 271)
    time.sleep(2)
    print('pyautogui')

# Digitar botão de estatisticas
    
try:
    estatisticas = browser.find_element("xpath", '//*[@id="horizontally-scrollable«re8»"]/div/div/div/button[2]')
    estatisticas.click()
except:
    estatisticas = browser.find_element("xpath", '//*[@id="horizontally-scrollable«r2ik»"]/div/div/div/button[6]')
    estatisticas.click()
# Out:
# Iraque
# pyautogui
# pyautogui

# %%
pyautogui.position()
# Out:
# Point(x=377, y=271)

# %%
for pais in ['Coreia do Sul','Iraque','Catar','Irã','Austrália','Jordânia','Arábia Saudita','Japão','Uzbequistão']:
    # Barra pesquisar
    pesquisa = browser.find_element("xpath", '/html/body/div[1]/div[4]/div/div[2]/div/div/div/div/svg')
    time.sleep(4)
    pesquisa.click()
    # Digitar a seleção
    digite = browser.find_element("xpath", '/html/body/div[5]/div[1]/div[1]/form/input')
    time.sleep(4)
    digite.send_keys(pais[1])
    print(pais[1])
    time.sleep(7)
    # Digitar botão de estatisticas
    estatisticas = browser.find_element("xpath", '/html/body/div[1]/main/div/div[1]/div[3]/div[1]/div/div/div/div/div/button[6]/a/h2')
    estatisticas.click()
    time.sleep(4)

htmls = [
            browser.find_element("xpath", '/html/body/div[1]/main/div/div[1]/div[3]/div[2]/div/div[2]/div[2]').get_attribute('outerHTML'),
            browser.find_element("xpath", '/html/body/div[1]/main/div/div[1]/div[3]/div[2]/div/div[2]/div[3]/div/div/div').get_attribute('outerHTML'),
            browser.find_element("xpath",'/html/body/div[1]/main/div/div[1]/div[3]/div[2]/div/div[2]/div[4]/div').get_attribute('outerHTML'),
            browser.find_element("xpath",'/html/body/div[1]/main/div/div[1]/div[3]/div[2]/div/div[2]/div[5]/div/div/div').get_attribute('outerHTML'),
            browser.find_element("xpath",'/html/body/div[1]/main/div/div[1]/div[3]/div[2]/div/div[2]/div[6]').get_attribute('outerHTML')
]
dados_finais = {}

for html in htmls:
    soup = BeautifulSoup(html, 'html.parser')

    spans = soup.find_all("span")
    textos = [s.get_text(strip=True) for s in spans]

    for i in range(0, len(textos), 2):
        if i + 1 < len(textos):
            chave = textos[i]
            valor = textos[i + 1]

            dados_finais[chave] = valor

print(dados_finais)
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Cell In[18], line 3
#       1 for pais in ['Coreia do Sul','Iraque','Catar','Irã','Austrália','Jordânia','Arábia Saudita','Japão','Uzbequistão']:
#       2     # Barra pesquisar
# ----> 3     pesquisa = browser.find_element("xpath", '/html/body/div[1]/div[4]/div/div[2]/div/div/div/div/svg')
#       4     time.sleep(4)
#       5     pesquisa.click()
#
# File c:\Users\Raphael\AppData\Local\Programs\Python\Python312\Lib\site-packages\selenium\webdriver\remote\webdriver.py:823, in WebDriver.find_element(self, by, value)
#     820         raise NoSuchElementException(f"Cannot locate relative element with: {by.root}")
#     821     return elements[0]
# --> 823 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File c:\Users\Raphael\AppData\Local\Programs\Python\Python312\Lib\site-packages\selenium\webdriver\remote\webdriver.py:450, in WebDriver.execute(self, driver_command, params)
#     447 response = cast(RemoteConnection, self.command_executor).execute(driver_command, params)
#     449 if response:
# --> 450     self.error_handler.check_response(response)
#     451     response["value"] = self._unwrap_value(response.get("value", None))
#     452     return response
#
# File c:\Users\Raphael\AppData\Local\Programs\Python\Python312\Lib\site-packages\selenium\webdriver\remote\errorhandler.py:232, in ErrorHandler.check_response(self, response)
#     230         alert_text = value["alert"].get("text")
#     231     raise exception_class(message, screen, stacktrace, alert_text)
# --> 232 raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"/html/body/div[1]/div[4]/div/div[2]/div/div/div/div/svg"}
#   (Session info: chrome=147.0.7727.57); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#nosuchelementexception
# Stacktrace:
# 	chromedriver!GetHandleVerifier [0xa1c733+10b73]
# 	chromedriver!GetHandleVerifier [0xa1c864+10ca4]
# 	chromedriver!(No symbol) [0x7f2100]
# 	chromedriver!(No symbol) [0x83acba]
# 	chromedriver!(No symbol) [0x83af5b]
# 	chromedriver!(No symbol) [0x87d9c2]
# 	chromedriver!(No symbol) [0x85dc64]
# 	chromedriver!(No symbol) [0x87b1f4]
# 	chromedriver!(No symbol) [0x85d9b6]
# 	chromedriver!(No symbol) [0x830339]
# 	chromedriver!(No symbol) [0x8310f4]
# 	chromedriver!GetHandleVerifier [0xc7fe04+274244]
# 	chromedriver!GetHandleVerifier [0xc7b459+26f899]
# 	chromedriver!GetHandleVerifier [0xc99bd5+28e015]
# 	chromedriver!GetHandleVerifier [0xa37188+2b5c8]
# 	chromedriver!GetHandleVerifier [0xa3f23d+3367d]
# 	chromedriver!GetHandleVerifier [0xa25138+19578]
# 	chromedriver!GetHandleVerifier [0xa25302+19742]
# 	chromedriver!GetHandleVerifier [0xa0e48f+28cf]
# 	KERNEL32!BaseThreadInitThunk [0x75225d49+19]
# 	ntdll!RtlInitializeExceptionChain [0x7774d5db+6b]
# 	ntdll!RtlGetAppContainerNamedObjectPath [0x7774d561+231]

# %%
for pais in dados:
    print(pais[1])
